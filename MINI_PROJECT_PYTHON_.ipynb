# %% [markdown]
# <a href="https://colab.research.google.com/github/kundanmrj5-dev/RANDOM-PASSWORD-GENERATOR-/blob/main/MINI_PROJECT_PYTHON_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MINI PROJECT (GUESS THE NUMBER , RANDOM => TARGETED)

# %% [markdown]
# RANDOM PASSWORD GENERATOR

# %%
import random
import string

pass_len= 10

charvalues = string.ascii_letters + string.digits + string.punctuation

# list comprehension [ function for i in range(n)]

password = "". join([random.choice(charvalues)for i in range(pass_len)])
# password = ""
# for i in range (pass_len):
# password += random.choice(charvalues)

print("your random is:",password)
# Out:
# your random is: r"NH\7b8Sz
